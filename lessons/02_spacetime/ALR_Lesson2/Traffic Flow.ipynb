# %%
t = 0.0
import numpy  
import sympy
from math import sin, cos, log, ceil
from sympy import init_printing
init_printing()
from sympy.utilities.lambdify import lambdify
import matplotlib.pyplot as plt    
# %matplotlib inline
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 16
#from JSAnimation.IPython_display import display_animation
from matplotlib import animation

# Model Parameters
V_max = 80. # km/h
L = 11. #km
rho_max = 250. # cars/km
nx = 51
dt = 0.001 # h

def velocity(rho):

    
    return V_max*(1-rho/rho_max)*1000/3600

### Check This
nt = int(6.0/60.0/dt+1) #nt is the number of time steps and our longest time is 6 minutes
dx = 0.1 #????? dx is the spacial time step
print(nt)
#Initial conditions
x = numpy.linspace(0,L,nx)
rho0 = numpy.ones(nx)*10
rho0[10:20] = 50
# rho(0,t) = 10
V0 = numpy.ones(nx)*velocity(10)
V0[10:20] = velocity(50)


#plt.plot(x, rho0, color='#003366', ls = '--', lw = 3)
#plt.ylim(0,60);



#def Velocity_time(t):  


rhon = numpy.ones(nx)
counter = 0

for n in range(0,nt):
    counter = counter+1
    if dt*(n+1)>(t/60.0):
        time = dt*n
        #print(time)
        break
    
   
    rhon = rho0.copy()
    
    for i in range(1,nx):
        
        rho0[i] = rhon[i]-dt/dx*V_max*(rhon[i]*(1-rhon[i]/rho_max)\
                                       -rhon[i-1]*(1-rhon[i-1]/rho_max))
        V0[i] = velocity(rho0[i])
            
V_ave = numpy.average(V0)
V_max = numpy.max(V0)    
V_min = numpy.min(V0)
time_spot = time*60
test = counter*dx*60
print('Average velocity {}'.format(V_ave)+ 'm/s')
print('Max velocity {}'.format(V_max)+ 'm/s')
print('Min velocity {}'.format(V_min)+ 'm/s')
print('Time location {}'.format(time_spot)+ 'min')
print('Time location {}'.format(time_spot)+ 'min')

plt.plot(x, V0, color='#003366', ls = '--', lw = 3)
plt.ylim(0,50);
# Out:
# 101
# Average velocity 20.6361655773m/s
# Max velocity 21.3333333333m/s
# Min velocity 17.7777777778m/s
# Time location 0.0min
# Time location 0.0min

# %%
t = 3.0
import numpy  
import sympy
from math import sin, cos, log, ceil
from sympy import init_printing
init_printing()
from sympy.utilities.lambdify import lambdify
import matplotlib.pyplot as plt    
# %matplotlib inline
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 16
#from JSAnimation.IPython_display import display_animation
from matplotlib import animation

# Model Parameters
V_max = 80. # km/h
L = 11. #km
rho_max = 250. # cars/km
nx = 51
dt = 0.001 # h

def velocity(rho):

    
    return V_max*(1-rho/rho_max)*1000/3600

### Check This
nt = int(6.0/60.0/dt+1) #nt is the number of time steps and our longest time is 6 minutes
dx = 0.1 #????? dx is the spacial time step
print(nt)
#Initial conditions
x = numpy.linspace(0,L,nx)
rho0 = numpy.ones(nx)*10
rho0[10:20] = 50
# rho(0,t) = 10
V0 = numpy.ones(nx)*velocity(10)
V0[10:20] = velocity(50)


#plt.plot(x, rho0, color='#003366', ls = '--', lw = 3)
#plt.ylim(0,60);




#def Velocity_time(t):  


rhon = numpy.ones(nx)
counter = 0

for n in range(0,nt):
    counter = counter+1
    if dt*(n+1)>(t/60.0):
        time = dt*n
        #print(time)
        break
    
   
    rhon = rho0.copy()
    
    for i in range(1,nx):
        
        rho0[i] = rhon[i]-dt/dx*V_max*(rhon[i]*(1-rhon[i]/rho_max)\
                                       -rhon[i-1]*(1-rhon[i-1]/rho_max))
        V0[i] = velocity(rho0[i])
            
V_ave = numpy.average(V0)
V_max = numpy.max(V0)    
V_min = numpy.min(V0)
time_spot = time*60
test = counter*dx*60
print('Average velocity {}'.format(V_ave)+ 'm/s')
print('Max velocity {}'.format(V_max)+ 'm/s')
print('Min velocity {}'.format(V_min)+ 'm/s')
print('Time location {}'.format(time_spot)+ 'min')
print('Time location {}'.format(time_spot)+ 'min')

plt.plot(x, V0, color='#003366', ls = '--', lw = 3)
plt.ylim(0,50);
# Out:
# 101
# Average velocity 20.7924441228m/s
# Max velocity 21.3333333333m/s
# Min velocity 18.4393886233m/s
# Time location 3.0min
# Time location 3.0min

# %% [markdown]
# Part 2

# %%
t = 0.0
import numpy  
import sympy
from math import sin, cos, log, ceil
from sympy import init_printing
init_printing()
from sympy.utilities.lambdify import lambdify
import matplotlib.pyplot as plt    
# %matplotlib inline
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 16
#from JSAnimation.IPython_display import display_animation
from matplotlib import animation

# Model Parameters
V_max = 136. # km/h
L = 11. #km
rho_max = 250. # cars/km
nx = 51
dt = 0.001 # h

def velocity(rho):

    
    return V_max*(1-rho/rho_max)*1000/3600

### Check This
nt = int(6.0/60.0/dt+1) #nt is the number of time steps and our longest time is 6 minutes
dx = 0.1 #????? dx is the spacial time step
print(nt)
#Initial conditions
x = numpy.linspace(0,L,nx)
rho0 = numpy.ones(nx)*20
rho0[10:20] = 50
# rho(0,t) = 10
V0 = numpy.ones(nx)*velocity(20)
V0[10:20] = velocity(50)


#plt.plot(x, rho0, color='#003366', ls = '--', lw = 3)
#plt.ylim(0,60);



#def Velocity_time(t):  


rhon = numpy.ones(nx)
counter = 0

for n in range(0,nt):
    counter = counter+1
    if dt*(n+1)>(t/60.0):
        time = dt*n
        #print(time)
        break
    
   
    rhon = rho0.copy()
    
    for i in range(1,nx):
        
        rho0[i] = rhon[i]-dt/dx*V_max*(rhon[i]*(1-rhon[i]/rho_max)\
                                       -rhon[i-1]*(1-rhon[i-1]/rho_max))
        V0[i] = velocity(rho0[i])
            
V_ave = numpy.average(V0)
V_max = numpy.max(V0)    
V_min = numpy.min(V0)
time_spot = time*60
test = counter*dx*60
print('Average velocity {}'.format(V_ave)+ 'm/s')
print('Max velocity {}'.format(V_max)+ 'm/s')
print('Min velocity {}'.format(V_min)+ 'm/s')
print('Time location {}'.format(time_spot)+ 'min')
print('Time location {}'.format(time_spot)+ 'min')

plt.plot(x, V0, color='#003366', ls = '--', lw = 3)
plt.ylim(0,50);
# Out:
# 101
# Average velocity 33.8666666667m/s
# Max velocity 34.7555555556m/s
# Min velocity 30.2222222222m/s
# Time location 0.0min
# Time location 0.0min

# %%
t = 3.0
import numpy  
import sympy
from math import sin, cos, log, ceil
from sympy import init_printing
init_printing()
from sympy.utilities.lambdify import lambdify
import matplotlib.pyplot as plt    
# %matplotlib inline
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 16
#from JSAnimation.IPython_display import display_animation
from matplotlib import animation

# Model Parameters
V_max = 136. # km/h
L = 11. #km
rho_max = 250. # cars/km
nx = 51
dt = 0.001 # h

def velocity(rho):

    
    return V_max*(1-rho/rho_max)*1000/3600

### Check This
nt = int(6.0/60.0/dt+1) #nt is the number of time steps and our longest time is 6 minutes
dx = V_max*dt/0.85 #????? dx is the spacial time step
print(nt)
print(dx)

#Initial conditions
x = numpy.linspace(0,L,nx)
rho0 = numpy.ones(nx)*20
rho0[10:20] = 50
# rho(0,t) = 10
V0 = numpy.ones(nx)*velocity(20)
V0[10:20] = velocity(50)


#plt.plot(x, rho0, color='#003366', ls = '--', lw = 3)
#plt.ylim(0,60);



#def Velocity_time(t):  


rhon = numpy.ones(nx)
counter = 0

for n in range(0,nt):
    counter = counter+1
    if dt*(n+1)>(t/60.0):
        time = dt*n
        #print(time)
        break
    
   
    rhon = rho0.copy()
    
    for i in range(1,nx):
        
        rho0[i] = rhon[i]-dt/dx*V_max*(rhon[i]*(1-rhon[i]/rho_max)\
                                       -rhon[i-1]*(1-rhon[i-1]/rho_max))
        V0[i] = velocity(rho0[i])
            
V_ave = numpy.average(V0)
V_max2 = numpy.max(V0)    
V_min = numpy.min(V0)
time_spot = time*60
test = counter*dx*60
print('Average velocity {}'.format(V_ave)+ 'm/s')
print('Max velocity {}'.format(V_max2)+ 'm/s')
print('Min velocity {}'.format(V_min)+ 'm/s')
print('Time location {}'.format(time_spot)+ 'min')
print('Time location {}'.format(time_spot)+ 'min')

plt.plot(x, V0, color='#003366', ls = '--', lw = 3)
plt.ylim(0,50);
# Out:
# 101
# 0.16
# Average velocity 34.0514072295m/s
# Max velocity 34.7555555556m/s
# Min velocity 31.0228637769m/s
# Time location 3.0min
# Time location 3.0min
